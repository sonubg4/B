# %%
import matplotlib.pyplot as plt
a=plt.axes()
a.set_facecolor("grey")
x=["2020","2021","2022"]
y=[100,150,80]
col=["orange","white","g"]
plt.bar(x,y,color=col,ec="k",width=0.2)
# Out:
# <BarContainer object of 3 artists>

# %%
import matplotlib.pyplot as plt
x=["2020","2021","2022"]
y=[100,150,80]
col=["orange","white","g"]
plt.subplot(2,2,1)
plt.bar(x,y,color=col,ec="k",width=0.2)
x=[4,1,1,4,4,1]
y=[4,4,3,3,2,2]
plt.subplot(2,2,2)
plt.grid()
plt.plot(x,y,color="black")

# %%
l=input()
if((l>='a' and l<='z') or (l>='A' and l<='Z')):
    if(l=='a' or l=='e' or l=='i' or l=='o' or l=='u' or l=='A' or l=='E' or l=='I' or l=='O' or l=='U'):
        print("vowel :",l)
    else:
        print("consonant :",l)
else:
        print("invalid input :",l)
# Out:
#  B
# consonant : B

# %%
a=int(input())
b=int(input())
sum=a+b
print(sum)
# Out:
#  90
#  10
# 100

# %%
for i in range(1,10):
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
